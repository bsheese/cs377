# %% [markdown]
# <a href="https://colab.research.google.com/github/bsheese/cs377/blob/main/18_classification/18_5_Ensemble/18_5_practice_quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Run the cell below to start the practice quiz.

# %%
# @title
import ipywidgets as widgets
from IPython.display import display, clear_output

# --- ALL QUIZ DATA ---
all_quizzes = {
    "18_5_0: Intro to Ensemble Methods": [
        {
            "question": "All ensemble methods share a core idea. What is it?",
            "options": [
                "Train one very deep model that captures all patterns in the data",
                "Combine multiple models to produce a single, more accurate prediction",
                "Use cross-validation to select the single best model from a candidate set",
                "Apply regularization to prevent any single model from overfitting"
            ],
            "answer": "Combine multiple models to produce a single, more accurate prediction"
        },
        {
            "question": "In the ensemble hierarchy, what is the primary goal of bagging?",
            "options": [
                "Reduce bias by sequentially correcting the errors of previous models",
                "Reduce variance by averaging the predictions of many independently trained models",
                "Provide uncertainty quantification through Bayesian posterior distributions",
                "Maximize interpretability by producing a single, simple decision tree"
            ],
            "answer": "Reduce variance by averaging the predictions of many independently trained models"
        },
        {
            "question": "How does boosting differ from bagging in how trees are built?",
            "options": [
                "Boosting builds trees in parallel on bootstrap samples, while bagging builds them sequentially",
                "Boosting builds trees sequentially, each correcting the errors of the ensemble so far, while bagging builds trees independently in parallel",
                "Boosting uses deep trees while bagging uses shallow trees",
                "Boosting uses random feature subsets at each split while bagging considers all features"
            ],
            "answer": "Boosting builds trees sequentially, each correcting the errors of the ensemble so far, while bagging builds trees independently in parallel"
        },
        {
            "question": "What is the primary goal of boosting in the ensemble framework?",
            "options": [
                "Reduce variance by averaging many diverse, uncorrelated predictions",
                "Reduce bias by taking weak models and making them stronger through sequential error correction",
                "Decorrelate trees by forcing each one to consider only a random subset of features",
                "Provide credible intervals for each individual prediction"
            ],
            "answer": "Reduce bias by taking weak models and making them stronger through sequential error correction"
        },
        {
            "question": "What unique capability does BART offer that standard ensemble methods do not?",
            "options": [
                "It trains significantly faster than Random Forest on large datasets",
                "It provides uncertainty quantification through credible intervals for each prediction",
                "It automatically handles missing values without any preprocessing",
                "It eliminates the need for hyperparameter tuning entirely"
            ],
            "answer": "It provides uncertainty quantification through credible intervals for each prediction"
        },
        {
            "question": "The Wisconsin Breast Cancer dataset contains how many samples and features?",
            "options": [
                "2,930 samples and 82 features",
                "569 samples and 30 features",
                "1,000 samples and 21 features",
                "569 samples and 10 features"
            ],
            "answer": "569 samples and 30 features"
        },
        {
            "question": "What is the approximate class distribution in the Wisconsin Breast Cancer dataset?",
            "options": [
                "50% benign, 50% malignant",
                "70% benign, 30% malignant",
                "63% benign, 37% malignant",
                "80% benign, 20% malignant"
            ],
            "answer": "63% benign, 37% malignant"
        },
        {
            "question": "In the breast cancer context, what does a false negative represent?",
            "options": [
                "The model predicts malignant but the tumor is actually benign — an unnecessary biopsy",
                "The model predicts benign but the tumor is actually malignant — a missed cancer",
                "The model correctly predicts benign and the tumor is actually benign",
                "The model produces a probability of exactly 0.5 for a malignant tumor"
            ],
            "answer": "The model predicts benign but the tumor is actually malignant — a missed cancer"
        },
        {
            "question": "Why is accuracy alone insufficient for evaluating a model on the breast cancer dataset?",
            "options": [
                "Because the dataset is too small for accuracy to be a reliable metric",
                "Because accuracy does not distinguish between false positives and false negatives, and in a medical context, missing a cancer is far more costly than an unnecessary biopsy",
                "Because accuracy can only be computed on balanced datasets",
                "Because accuracy requires the model to output probabilities rather than class labels"
            ],
            "answer": "Because accuracy does not distinguish between false positives and false negatives, and in a medical context, missing a cancer is far more costly than an unnecessary biopsy"
        },
        {
            "question": "A naive model that always predicts 'benign' on the breast cancer dataset would achieve approximately what accuracy?",
            "options": [
                "37%",
                "50%",
                "63%",
                "95%"
            ],
            "answer": "63%"
        },
        {
            "question": "What does the 'wisdom of the crowd' principle mean in the context of ensemble methods?",
            "options": [
                "The largest model in the ensemble should dominate the final prediction",
                "Averaging the predictions of many diverse, independent models produces a more accurate result than any single model",
                "The model with the highest cross-validation score should be selected as the final model",
                "Human experts should always review and override model predictions in high-stakes applications"
            ],
            "answer": "Averaging the predictions of many diverse, independent models produces a more accurate result than any single model"
        },
        {
            "question": "How does a Random Forest differ from plain bagging?",
            "options": [
                "Random Forest uses fewer trees, making it faster to train",
                "Random Forest builds trees sequentially while bagging builds them in parallel",
                "Random Forest considers only a random subset of features at each split, decorrelating the trees beyond what bagging achieves",
                "Random Forest uses shallow trees while bagging uses deep trees"
            ],
            "answer": "Random Forest considers only a random subset of features at each split, decorrelating the trees beyond what bagging achieves"
        },
        {
            "question": "Why is the breast cancer dataset described as a 'high-stakes classification problem'?",
            "options": [
                "Because the dataset is very large and requires significant computational resources",
                "Because the features are difficult to measure accurately in clinical practice",
                "Because the costs of the two types of errors are asymmetric — missing a cancer has far more severe consequences than an unnecessary biopsy",
                "Because the class distribution is perfectly balanced, making it hard to achieve high accuracy"
            ],
            "answer": "Because the costs of the two types of errors are asymmetric — missing a cancer has far more severe consequences than an unnecessary biopsy"
        },
        {
            "question": "In the ensemble hierarchy table, what does 'Bayesian tree perturbation' refer to?",
            "options": [
                "The process of randomly removing trees from the ensemble to improve speed",
                "The MCMC-based process in BART of randomly adding branches, removing splits, and changing thresholds across the ensemble",
                "The bootstrap sampling process used in bagging to create diverse training sets",
                "The sequential reweighting of samples in AdaBoost"
            ],
            "answer": "The MCMC-based process in BART of randomly adding branches, removing splits, and changing thresholds across the ensemble"
        },
        {
            "question": "What is the relationship between bagging/random forests and variance?",
            "options": [
                "They increase variance by training many different models on different data",
                "They reduce variance by averaging many independently overfitting models, canceling out their individual errors",
                "They have no effect on variance — variance is only affected by the number of features",
                "They reduce variance by using shallow trees that cannot overfit"
            ],
            "answer": "They reduce variance by averaging many independently overfitting models, canceling out their individual errors"
        },
        {
            "question": "What is the relationship between boosting and bias?",
            "options": [
                "Boosting increases bias by using shallow trees that cannot capture complex patterns",
                "Boosting has no effect on bias — it only reduces variance",
                "Boosting reduces bias by sequentially correcting errors, turning weak learners into a strong ensemble",
                "Boosting reduces bias by using deeper trees than bagging"
            ],
            "answer": "Boosting reduces bias by sequentially correcting errors, turning weak learners into a strong ensemble"
        },
        {
            "question": "The 18_5 series uses the Wisconsin Breast Cancer dataset instead of the Ames Housing dataset used in 18_1. Why is this a meaningful change?",
            "options": [
                "Because the breast cancer dataset is larger and provides more reliable results",
                "Because the breast cancer dataset is a classification problem with asymmetric error costs, requiring different evaluation metrics than the regression problem in 18_1",
                "Because the Ames Housing dataset was too clean and did not demonstrate real-world challenges",
                "Because the breast cancer dataset has fewer features, making it easier to visualize"
            ],
            "answer": "Because the breast cancer dataset is a classification problem with asymmetric error costs, requiring different evaluation metrics than the regression problem in 18_1"
        },
        {
            "question": "What does it mean that ensemble methods 'combine multiple weak models to create a strong one'?",
            "options": [
                "Each individual model in the ensemble must perform worse than random guessing",
                "The ensemble's combined prediction is more accurate than any individual model's prediction, even if some individual models are quite good",
                "The ensemble discards the weakest models and only uses the strongest ones",
                "The ensemble assigns zero weight to models that perform below a certain threshold"
            ],
            "answer": "The ensemble's combined prediction is more accurate than any individual model's prediction, even if some individual models are quite good"
        },
        {
            "question": "In the context of the breast cancer dataset, what would be the clinical consequence of optimizing a model purely for accuracy?",
            "options": [
                "The model would achieve perfect accuracy because the dataset is well-separated",
                "The model might achieve high accuracy by correctly classifying most benign tumors while missing a significant fraction of malignant ones",
                "The model would automatically balance false positives and false negatives",
                "The model would require more features to achieve high accuracy"
            ],
            "answer": "The model might achieve high accuracy by correctly classifying most benign tumors while missing a significant fraction of malignant ones"
        },
        {
            "question": "What is the 'majority vote' mechanism in bagging and random forests?",
            "options": [
                "Each tree votes for a class, and the class with the most votes becomes the final prediction",
                "The model with the highest cross-validation score is selected as the final model",
                "Each feature votes for its importance score, and the top features are used for prediction",
                "The training samples vote on which class they belong to based on their nearest neighbors"
            ],
            "answer": "Each tree votes for a class, and the class with the most votes becomes the final prediction"
        },
        {
            "question": "Why does the notebook recommend reviewing the 18_1_5 notebook before starting 18_5?",
            "options": [
                "Because 18_1_5 covers the same dataset and provides the data cleaning steps needed for 18_5",
                "Because 18_1_5 introduced tree-based methods that 18_5 builds upon with deeper analysis",
                "Because 18_1_5 covers the mathematical proofs behind ensemble methods",
                "Because 18_1_5 contains the code for BART that is used in 18_5"
            ],
            "answer": "Because 18_1_5 introduced tree-based methods that 18_5 builds upon with deeper analysis"
        },
        {
            "question": "What does 'decorrelate' mean in the context of Random Forests?",
            "options": [
                "Remove correlated features from the dataset before training",
                "Make individual trees less similar to each other by restricting the features they can consider at each split, so that averaging them is more effective",
                "Ensure that the training and test sets have no correlated features",
                "Force each tree to use a completely different set of features"
            ],
            "answer": "Make individual trees less similar to each other by restricting the features they can consider at each split, so that averaging them is more effective"
        },
        {
            "question": "If a model on the breast cancer dataset achieves 95% accuracy but has a malignant recall of 70%, what does this mean?",
            "options": [
                "The model is excellent — 95% accuracy is very high for any medical application",
                "The model correctly identifies 95% of all tumors but misses 30% of actual cancers, which may be clinically unacceptable",
                "The model is overfitting and should be retrained with more data",
                "The model's accuracy and recall are inconsistent, indicating a bug in the evaluation code"
            ],
            "answer": "The model correctly identifies 95% of all tumors but misses 30% of actual cancers, which may be clinically unacceptable"
        },
        {
            "question": "What is the 'weighted sum' mechanism in boosting?",
            "options": [
                "Each tree's prediction is multiplied by a weight reflecting its performance, and the weighted predictions are summed for the final output",
                "Each feature is assigned a weight based on its importance, and the weighted features are summed",
                "Each training sample is weighted by its class frequency, and the weighted samples are summed",
                "The final prediction is the sum of all tree predictions divided by the number of trees"
            ],
            "answer": "Each tree's prediction is multiplied by a weight reflecting its performance, and the weighted predictions are summed for the final output"
        },
        {
            "question": "The notebook states that BART addresses 'both' bias and variance. What does this mean?",
            "options": [
                "BART uses both deep and shallow trees in the same ensemble",
                "BART combines the variance-reduction benefits of ensemble averaging with the bias-reduction benefits of sequential refinement, while also providing uncertainty estimates",
                "BART trains two separate models — one for bias and one for variance — and combines their predictions",
                "BART uses both L1 and L2 regularization to control bias and variance simultaneously"
            ],
            "answer": "BART combines the variance-reduction benefits of ensemble averaging with the bias-reduction benefits of sequential refinement, while also providing uncertainty estimates"
        },
        {
            "question": "Why does the notebook emphasize looking 'beyond accuracy' for the breast cancer problem?",
            "options": [
                "Because accuracy is computationally expensive to calculate on large datasets",
                "Because accuracy treats all errors equally, but in medical diagnosis, the cost of a false negative far exceeds the cost of a false positive",
                "Because accuracy can only be used for regression problems, not classification",
                "Because the breast cancer dataset is too imbalanced for accuracy to be computable"
            ],
            "answer": "Because accuracy treats all errors equally, but in medical diagnosis, the cost of a false negative far exceeds the cost of a false positive"
        },
        {
            "question": "What is the significance of the 'mean, standard error, and worst' feature structure in the breast cancer dataset?",
            "options": [
                "It means each of the 10 cell nucleus characteristics is measured three ways, producing 30 features total",
                "It means the dataset has been preprocessed to remove outliers",
                "It means the features are already standardized and require no scaling",
                "It means the dataset contains three separate target variables"
            ],
            "answer": "It means each of the 10 cell nucleus characteristics is measured three ways, producing 30 features total"
        },
        {
            "question": "In the ensemble hierarchy, what distinguishes a single decision tree from all ensemble methods?",
            "options": [
                "A single tree can only handle binary classification while ensembles can handle multiclass",
                "A single tree is built top-down without combining multiple models, making it interpretable but unstable",
                "A single tree requires feature scaling while ensemble methods do not",
                "A single tree always overfits while ensemble methods never overfit"
            ],
            "answer": "A single tree is built top-down without combining multiple models, making it interpretable but unstable"
        }
    ],
        "18_5_1: Decision Trees \u2014 The Foundation": [
        {
            "question": "In a classification tree, what does each leaf node predict?",
            "options": [
                "The mean of target values in the leaf, as in regression trees",
                "The majority class of training samples that reach that leaf",
                "The median of target values in the leaf to reduce the effect of outliers",
                "A weighted average of all class probabilities from the parent nodes"
            ],
            "answer": "The majority class of training samples that reach that leaf"
        },
        {
            "question": "What does Gini impurity measure at a decision tree node?",
            "options": [
                "The number of samples that reach that node during training",
                "The depth of the node relative to the root of the tree",
                "How mixed the classes are in the node, where 0 means pure and 0.5 means maximally mixed for binary classification",
                "The total reduction in error achieved by splitting on this node"
            ],
            "answer": "How mixed the classes are in the node, where 0 means pure and 0.5 means maximally mixed for binary classification"
        },
        {
            "question": "A node in a binary classification tree contains 80 malignant and 20 benign samples. What is its Gini impurity?",
            "options": [
                "0.16, calculated as 0.8 squared plus 0.2 squared",
                "0.32, calculated as 1 minus (0.8 squared plus 0.2 squared)",
                "0.50, because the node contains two different classes",
                "0.80, because 80% of the samples are malignant"
            ],
            "answer": "0.32, calculated as 1 minus (0.8 squared plus 0.2 squared)"
        },
        {
            "question": "How does a classification tree choose which feature and threshold to split on at each node?",
            "options": [
                "It randomly selects a feature and uses the median as the threshold",
                "It tries every possible split on every feature and picks the one that produces the greatest reduction in Gini impurity",
                "It selects the feature with the highest correlation to the target variable",
                "It uses the feature that was most important in the parent node's split"
            ],
            "answer": "It tries every possible split on every feature and picks the one that produces the greatest reduction in Gini impurity"
        },
        {
            "question": "What is the relationship between Gini impurity and entropy as split criteria in decision trees?",
            "options": [
                "Gini impurity and entropy always produce completely different tree structures",
                "Gini impurity is used for regression trees while entropy is used for classification trees",
                "In practice, they produce nearly identical trees, and scikit-learn uses Gini impurity by default",
                "Entropy is computationally faster while Gini impurity is more accurate"
            ],
            "answer": "In practice, they produce nearly identical trees, and scikit-learn uses Gini impurity by default"
        },
        {
            "question": "In the depth experiment, why does training accuracy climb to 1.0 as tree depth increases?",
            "options": [
                "Because the model is generalizing well to unseen data at greater depths",
                "Because the tree is memorizing the training data by creating increasingly specific splits for individual samples",
                "Because deeper trees have fewer parameters and are therefore less prone to error",
                "Because the training set becomes larger as the tree grows deeper"
            ],
            "answer": "Because the tree is memorizing the training data by creating increasingly specific splits for individual samples"
        },
        {
            "question": "In the depth experiment, the best depth for testing accuracy was 3, but the best depth for malignant recall was 8. What does this tell us?",
            "options": [
                "The recall calculation is incorrect because it should always peak at the same depth as accuracy",
                "A tree optimized for overall accuracy may miss more cancers than a slightly deeper tree that catches more malignancies",
                "Deeper trees always have higher recall regardless of their impact on accuracy",
                "The training data is too small to produce reliable results for either metric"
            ],
            "answer": "A tree optimized for overall accuracy may miss more cancers than a slightly deeper tree that catches more malignancies"
        },
        {
            "question": "What does the gap between the training accuracy curve and the testing accuracy curve represent?",
            "options": [
                "The model's bias — how far it is from capturing the true underlying pattern",
                "The overfitting penalty — how much the model's performance degrades on unseen data compared to training data",
                "The effect of class imbalance on the model's predictions",
                "The measurement error inherent in the test set"
            ],
            "answer": "The overfitting penalty — how much the model's performance degrades on unseen data compared to training data"
        },
        {
            "question": "In the confusion matrix for the decision tree, what does a false negative represent in the breast cancer context?",
            "options": [
                "The model predicts malignant but the tumor is actually benign — an unnecessary biopsy",
                "The model predicts benign but the tumor is actually malignant — a missed cancer",
                "The model correctly predicts benign and the tumor is actually benign",
                "The model produces a probability of exactly 0.5 for a malignant tumor"
            ],
            "answer": "The model predicts benign but the tumor is actually malignant — a missed cancer"
        },
        {
            "question": "In the confusion matrix for the decision tree, what does a false positive represent in the breast cancer context?",
            "options": [
                "The model predicts malignant but the tumor is actually benign — an unnecessary biopsy",
                "The model predicts benign but the tumor is actually malignant — a missed cancer",
                "The model correctly predicts malignant and the tumor is actually malignant",
                "The model fails to produce a prediction for that sample"
            ],
            "answer": "The model predicts malignant but the tumor is actually benign — an unnecessary biopsy"
        },
        {
            "question": "Why is the malignant recall arguably more important than overall accuracy in the breast cancer context?",
            "options": [
                "Because recall is always a more reliable metric than accuracy for any classification problem",
                "Because missing a cancer (false negative) has far more severe clinical consequences than an unnecessary biopsy (false positive)",
                "Because accuracy cannot be computed on imbalanced datasets",
                "Because recall measures the model's ability to predict benign tumors, which are the majority class"
            ],
            "answer": "Because missing a cancer (false negative) has far more severe clinical consequences than an unnecessary biopsy (false positive)"
        },
        {
            "question": "What does an AUC of 0.919 mean for the decision tree model on the breast cancer dataset?",
            "options": [
                "The model correctly classifies 91.9% of all tumors in the test set",
                "If you randomly pick one malignant and one benign tumor, the model correctly ranks the malignant one as higher-risk 91.9% of the time",
                "The model has a 91.9% probability of being correct on any single prediction",
                "The model's precision is 91.9% for the malignant class"
            ],
            "answer": "If you randomly pick one malignant and one benign tumor, the model correctly ranks the malignant one as higher-risk 91.9% of the time"
        },
        {
            "question": "The ROC curve shows the trade-off between true positive rate and false positive rate. What happens to these two rates as you lower the decision threshold from 0.5 toward 0?",
            "options": [
                "Both TPR and FPR decrease, because the model becomes more conservative",
                "TPR increases and FPR increases, because the model flags more samples as positive, catching more cancers but also generating more false alarms",
                "TPR decreases and FPR increases, because the model becomes less reliable overall",
                "Both TPR and FPR remain constant, because the ROC curve is independent of the threshold"
            ],
            "answer": "TPR increases and FPR increases, because the model flags more samples as positive, catching more cancers but also generating more false alarms"
        },
        {
            "question": "In the 10-fold cross-validation results, the malignant recall has a standard deviation of 0.058. What does this tell you?",
            "options": [
                "The model's recall varies by about 5.8 percentage points depending on which samples end up in each fold, indicating moderate instability",
                "The model misses exactly 5.8% of cancers in every fold",
                "The model's recall is 5.8% higher than its accuracy on average",
                "The standard deviation is too small to be meaningful and can be ignored"
            ],
            "answer": "The model's recall varies by about 5.8 percentage points depending on which samples end up in each fold, indicating moderate instability"
        },
        {
            "question": "The cross-validation results show malignant recall ranging from 0.824 to 1.000 across folds. What is the clinical implication of this range?",
            "options": [
                "The model is perfectly reliable because the minimum recall is above 80%",
                "In the worst fold, the model misses about 1 in 6 cancers, while in the best fold it catches all of them — this variability is a concern for clinical deployment",
                "The range indicates a bug in the cross-validation code, as recall should be constant across folds",
                "The model should only be deployed on datasets similar to the best-performing fold"
            ],
            "answer": "In the worst fold, the model misses about 1 in 6 cancers, while in the best fold it catches all of them — this variability is a concern for clinical deployment"
        },
        {
            "question": "Why does the notebook flip the target encoding so that 1 = malignant and 0 = benign?",
            "options": [
                "Because scikit-learn requires the positive class to be encoded as 1",
                "Because malignant is the clinically important class (the 'positive' class we want to detect), and encoding it as 1 makes recall and other metrics refer to malignancy",
                "Because the original dataset had an error in its encoding that needed correction",
                "Because flipping the encoding improves the model's accuracy"
            ],
            "answer": "Because malignant is the clinically important class (the 'positive' class we want to detect), and encoding it as 1 makes recall and other metrics refer to malignancy"
        },
        {
            "question": "What is the key difference between a regression tree (from 18_1_5) and a classification tree (from 18_5_1) in terms of leaf predictions?",
            "options": [
                "Regression trees predict the median while classification trees predict the mode",
                "Regression trees predict the mean of target values in the leaf while classification trees predict the majority class",
                "Regression trees predict a probability while classification trees predict a hard class label",
                "There is no difference — both predict the mean of their target values"
            ],
            "answer": "Regression trees predict the mean of target values in the leaf while classification trees predict the majority class"
        },
        {
            "question": "What is the key difference between a regression tree and a classification tree in terms of split criterion?",
            "options": [
                "Regression trees minimize Mean Squared Error while classification trees minimize Gini impurity or entropy",
                "Regression trees use Gini impurity while classification trees use Mean Squared Error",
                "Regression trees use accuracy while classification trees use R-squared",
                "There is no difference — both use Gini impurity"
            ],
            "answer": "Regression trees minimize Mean Squared Error while classification trees minimize Gini impurity or entropy"
        },
        {
            "question": "In the tree visualization, what does the 'value' field in each node represent?",
            "options": [
                "The Gini impurity of that node",
                "The number of samples that reach that node",
                "The count of samples in each class that reach that node, shown as [benign count, malignant count]",
                "The predicted probability of malignancy for that node"
            ],
            "answer": "The count of samples in each class that reach that node, shown as [benign count, malignant count]"
        },
        {
            "question": "In the tree visualization, what does the color intensity of each node indicate?",
            "options": [
                "The depth of the node in the tree — darker nodes are deeper",
                "The number of samples in the node — darker nodes have more samples",
                "The purity of the node — darker nodes are purer (more dominated by one class)",
                "The importance of the feature used to split at that node"
            ],
            "answer": "The purity of the node — darker nodes are purer (more dominated by one class)"
        },
        {
            "question": "The root node of the depth-3 tree splits on 'mean concave points <= 0.051'. Why is this significant?",
            "options": [
                "It is a random choice — the tree could have split on any feature first",
                "It confirms that 'mean concave points' is the single most discriminative feature for separating malignant from benign tumors, consistent with the violin plot analysis",
                "It means that concave points are the only feature that matters for classification",
                "It indicates that the tree is overfitting to this particular feature"
            ],
            "answer": "It confirms that 'mean concave points' is the single most discriminative feature for separating malignant from benign tumors, consistent with the violin plot analysis"
        },
        {
            "question": "Why does the notebook use violin plots rather than histograms to visualize feature distributions by class?",
            "options": [
                "Because violin plots are faster to compute than histograms",
                "Because violin plots show the full distribution shape for each class side by side, making it easy to see overlap and separation between benign and malignant groups",
                "Because histograms cannot handle continuous variables",
                "Because violin plots are the only visualization that works with scikit-learn"
            ],
            "answer": "Because violin plots show the full distribution shape for each class side by side, making it easy to see overlap and separation between benign and malignant groups"
        },
        {
            "question": "What does 'good differentiation' mean when examining the violin plots of features by class?",
            "options": [
                "The two class distributions have minimal overlap, meaning the feature clearly separates benign from malignant tumors",
                "The feature has a high mean value for both classes",
                "The feature has low variance within each class",
                "The feature is not correlated with any other feature in the dataset"
            ],
            "answer": "The two class distributions have minimal overlap, meaning the feature clearly separates benign from malignant tumors"
        },
        {
            "question": "Why is stratification used in the train/test split for this classification problem?",
            "options": [
                "Because stratification ensures the model trains faster",
                "Because stratification preserves the 63/37 class distribution in both training and test sets, preventing a split that accidentally has very few malignant samples",
                "Because stratification is required for decision trees to work correctly",
                "Because stratification eliminates the need for cross-validation"
            ],
            "answer": "Because stratification preserves the 63/37 class distribution in both training and test sets, preventing a split that accidentally has very few malignant samples"
        },
        {
            "question": "The cross-validation results show the model misses roughly 1 in 11 cancers. If this model were used to screen 10,000 patients with the same cancer rate as the dataset, approximately how many cancers would be missed?",
            "options": [
                "About 37 cancers, because 37% of patients have cancer and 1 in 11 of those would be missed",
                "About 336 cancers, because 37% of 10,000 is 3,700 cancers and roughly 1 in 11 of those (about 9%) would be missed",
                "About 909 cancers, because 1 in 11 of all 10,000 patients would be missed",
                "About 11 cancers, because the model misses 1 in 11 patients regardless of cancer rate"
            ],
            "answer": "About 336 cancers, because 37% of 10,000 is 3,700 cancers and roughly 1 in 11 of those (about 9%) would be missed"
        },
        {
            "question": "In the classification report, the malignant class has precision of 1.00 and recall of 0.78. What does this combination mean?",
            "options": [
                "Every time the model predicts malignant, it is correct (no false positives), but it only catches 78% of actual malignancies (missing 22%)",
                "The model catches 100% of malignancies but also generates many false positives",
                "The model is equally good at precision and recall, with an average of 0.89",
                "The model's precision and recall are inconsistent, indicating a bug in the evaluation"
            ],
            "answer": "Every time the model predicts malignant, it is correct (no false positives), but it only catches 78% of actual malignancies (missing 22%)"
        },
        {
            "question": "Why does the notebook track malignant recall alongside accuracy in the depth experiment, rather than just accuracy alone?",
            "options": [
                "Because recall is mathematically easier to compute than accuracy for decision trees",
                "Because in a medical context, the cost of missing a cancer is asymmetric and far more severe than the cost of a false positive, so accuracy alone masks this critical distinction",
                "Because accuracy cannot be computed for trees deeper than 5",
                "Because recall is the only metric that scikit-learn supports for classification trees"
            ],
            "answer": "Because in a medical context, the cost of missing a cancer is asymmetric and far more severe than the cost of a false positive, so accuracy alone masks this critical distinction"
        }
    ],
        "18_5_2: Bagging and Random Forests": [
        {
            "question": "What is the core mechanism by which bagging (bootstrap aggregating) reduces model variance?",
            "options": [
                "By training each model on a completely different set of features, ensuring no two models see the same information",
                "By training many models independently on bootstrap samples and averaging their predictions, so that individual overfitting errors cancel out",
                "By sequentially correcting the errors of previous models, gradually reducing the overall bias of the ensemble",
                "By selecting only the best-performing models from a large candidate pool and discarding the rest"
            ],
            "answer": "By training many models independently on bootstrap samples and averaging their predictions, so that individual overfitting errors cancel out"
        },
        {
            "question": "In bootstrap sampling, approximately what proportion of the original training data is left out of each bootstrap sample on average?",
            "options": [
                "About 10%, because only a small fraction of samples are excluded during sampling with replacement",
                "About 37%, because the probability that any given sample is not selected in n draws with replacement approaches 1/e as n grows large",
                "About 50%, because sampling with replacement naturally excludes half the data",
                "About 63%, because that is the proportion of samples that appear at least once in the bootstrap sample"
            ],
            "answer": "About 37%, because the probability that any given sample is not selected in n draws with replacement approaches 1/e as n grows large"
        },
        {
            "question": "Why does bagging use deep (unlimited depth) decision trees rather than shallow ones?",
            "options": [
                "Because deep trees are computationally faster to train than shallow trees when used in large ensembles",
                "Because shallow trees cannot be combined through majority voting — they produce incompatible predictions",
                "Because bagging relies on each tree being individually strong (but overfitting differently) so that averaging cancels their individual errors, whereas shallow trees would all be weak and averaging weak models does not help much",
                "Because deep trees have lower variance than shallow trees, making them inherently more stable"
            ],
            "answer": "Because bagging relies on each tree being individually strong (but overfitting differently) so that averaging cancels their individual errors, whereas shallow trees would all be weak and averaging weak models does not help much"
        },
        {
            "question": "What is Out-of-Bag (OOB) error and why is it useful in bagging-based methods?",
            "options": [
                "It is the error on the training set, used to check whether the model has converged during training",
                "It is the error on a separate held-out validation set that must be set aside before training begins",
                "It is the error computed on the samples left out of each bootstrap sample, providing a built-in validation estimate without needing a separate test set",
                "It is the error on the test set, used to report the final model performance after all training is complete"
            ],
            "answer": "It is the error computed on the samples left out of each bootstrap sample, providing a built-in validation estimate without needing a separate test set"
        },
        {
            "question": "Why is the OOB score typically very close to the test accuracy for bagging-based models?",
            "options": [
                "Because the OOB samples were never seen by the individual trees that were trained without them, making OOB a genuine out-of-sample estimate similar to a test set",
                "Because the OOB score is computed on the same data as the test set, making them mathematically identical",
                "Because bagging models always achieve perfect accuracy, so both OOB and test scores converge to 1.0",
                "Because the OOB score is specifically calibrated to match the test accuracy during the training process"
            ],
            "answer": "Because the OOB samples were never seen by the individual trees that were trained without them, making OOB a genuine out-of-sample estimate similar to a test set"
        },
        {
            "question": "Why is OOB error not available for boosting methods like Gradient Boosting?",
            "options": [
                "Because boosting methods do not use bootstrap sampling — each tree is trained on the full dataset, so there are no out-of-bag samples",
                "Because boosting methods are too computationally expensive to compute an additional error metric",
                "Because OOB error is only defined for classification problems, and boosting is used exclusively for regression",
                "Because boosting methods automatically include a built-in validation set as part of their sequential training process"
            ],
            "answer": "Because boosting methods do not use bootstrap sampling — each tree is trained on the full dataset, so there are no out-of-bag samples"
        },
        {
            "question": "How does a Random Forest differ from plain bagging?",
            "options": [
                "Random Forest uses fewer trees than bagging, making it faster to train while achieving similar accuracy",
                "Random Forest considers only a random subset of features at each split, decorrelating the trees beyond what bagging achieves with bootstrap sampling alone",
                "Random Forest builds trees sequentially, with each tree correcting the errors of the previous ensemble",
                "Random Forest uses shallow trees while bagging uses deep trees, resulting in different bias-variance tradeoffs"
            ],
            "answer": "Random Forest considers only a random subset of features at each split, decorrelating the trees beyond what bagging achieves with bootstrap sampling alone"
        },
        {
            "question": "What does 'decorrelating the trees' mean in the context of Random Forests, and why is it important?",
            "options": [
                "It means removing correlated features from the dataset before training, which simplifies the model and reduces overfitting",
                "It means making individual trees less similar to each other by restricting the features they can consider at each split, so that averaging their predictions is more effective at reducing variance",
                "It means ensuring that the training and test sets share no correlated features, which prevents data leakage",
                "It means forcing each tree to use a completely disjoint set of features, so that no feature is used by more than one tree"
            ],
            "answer": "It means making individual trees less similar to each other by restricting the features they can consider at each split, so that averaging their predictions is more effective at reducing variance"
        },
        {
            "question": "In Random Forests, the default number of features considered at each split is the square root of the total number of features (√p). What would happen if we instead considered all features at every split?",
            "options": [
                "The model would become a plain bagging ensemble, losing the decorrelation benefit and likely achieving slightly higher variance",
                "The model would become equivalent to Gradient Boosting, building trees sequentially rather than in parallel",
                "The model would fail to train because Random Forests require feature randomness to function",
                "The model would achieve perfect accuracy because considering all features gives each tree maximum information"
            ],
            "answer": "The model would become a plain bagging ensemble, losing the decorrelation benefit and likely achieving slightly higher variance"
        },
        {
            "question": "What effect does class_weight='balanced' typically have on a Random Forest trained on an imbalanced medical dataset?",
            "options": [
                "It increases overall accuracy by ignoring the minority class and focusing only on the majority class",
                "It shifts the decision boundary to catch more instances of the minority class (e.g., more malignancies) at the cost of more false positives (e.g., more unnecessary biopsies)",
                "It reduces the number of trees needed in the forest by automatically selecting the most informative trees",
                "It eliminates the need for cross-validation by internally balancing the class distribution during training"
            ],
            "answer": "It shifts the decision boundary to catch more instances of the minority class (e.g., more malignancies) at the cost of more false positives (e.g., more unnecessary biopsies)"
        },
        {
            "question": "In the class_weight comparison, both default and balanced weights achieved the same accuracy and recall on this particular dataset. What might explain this?",
            "options": [
                "The class_weight parameter has no effect on Random Forests and is only useful for logistic regression",
                "The dataset may not be imbalanced enough, or the default model may already be catching most malignancies, leaving little room for improvement from rebalancing",
                "The balanced weights setting was incorrectly applied and defaulted to the standard weighting scheme",
                "Random Forests are inherently immune to class imbalance and never require class weighting"
            ],
            "answer": "The dataset may not be imbalanced enough, or the default model may already be catching most malignancies, leaving little room for improvement from rebalancing"
        },
        {
            "question": "How is feature importance computed in a Random Forest?",
            "options": [
                "By counting how many times each feature appears in the trees, with more frequent features receiving higher importance",
                "By measuring the total reduction in Gini impurity (or MSE for regression) attributed to splits on each feature across all trees, normalized to sum to 1.0",
                "By computing the correlation between each feature and the target variable across the entire dataset",
                "By training a separate model with each feature removed and measuring the drop in accuracy"
            ],
            "answer": "By measuring the total reduction in Gini impurity (or MSE for regression) attributed to splits on each feature across all trees, normalized to sum to 1.0"
        },
        {
            "question": "Why do correlated features share importance in a Random Forest, and what is the consequence?",
            "options": [
                "Because the model assigns equal importance to all features by design, regardless of their predictive power",
                "Because the model tends to pick one correlated feature for splits and the others get little or no credit, so the importance is split among them and none appears as dominant as it truly is",
                "Because correlated features are automatically removed during training, leaving only one representative from each correlated group",
                "Because the importance calculation only considers the first feature alphabetically when features are correlated"
            ],
            "answer": "Because the model tends to pick one correlated feature for splits and the others get little or no credit, so the importance is split among them and none appears as dominant as it truly is"
        },
        {
            "question": "What is permutation importance and why is it more reliable than impurity-based importance when features are correlated?",
            "options": [
                "Permutation importance randomly shuffles the values of a single feature and measures the drop in model performance, evaluating each feature's contribution independently of the others",
                "Permutation importance reorders the training samples by their target values and measures how well the model predicts the sorted sequence",
                "Permutation importance trains a separate model for each possible permutation of the feature set and averages the results",
                "Permutation importance is identical to impurity-based importance but uses a different mathematical formula to compute the same values"
            ],
            "answer": "Permutation importance randomly shuffles the values of a single feature and measures the drop in model performance, evaluating each feature's contribution independently of the others"
        },
        {
            "question": "In the 10-fold cross-validation comparison, the Random Forest has a lower standard deviation than both the single tree and bagging. What does this indicate?",
            "options": [
                "The Random Forest is slower to train because it requires more computational resources per fold",
                "The Random Forest's performance is more consistent across different data splits, meaning it is more stable and reliable for deployment",
                "The Random Forest has a higher bias than the single tree, making it less sensitive to the specific training samples",
                "The Random Forest uses fewer features than bagging, which naturally reduces the variance of its predictions"
            ],
            "answer": "The Random Forest's performance is more consistent across different data splits, meaning it is more stable and reliable for deployment"
        },
        {
            "question": "In the GridSearchCV tuning of the Random Forest, the best model used only 100 trees while the default used 500. What does this tell us about the relationship between n_estimators and model performance?",
            "options": [
                "More trees always means better performance, so the default of 500 trees should always be preferred",
                "Beyond a certain point, adding more trees provides diminishing returns, and tuning can find a simpler model with comparable performance",
                "The GridSearchCV algorithm is biased toward selecting models with fewer trees to reduce computation time",
                "Random Forests with fewer than 200 trees are fundamentally unstable and should never be used in practice"
            ],
            "answer": "Beyond a certain point, adding more trees provides diminishing returns, and tuning can find a simpler model with comparable performance"
        },
        {
            "question": "Why does the notebook use F1-score as the scoring metric for GridSearchCV rather than accuracy?",
            "options": [
                "Because F1-score is computationally faster to compute than accuracy during cross-validation",
                "Because F1-score balances precision and recall, which is important in a medical context where both false positives and false negatives matter, and accuracy alone can be misleading on imbalanced data",
                "Because scikit-learn does not support accuracy as a scoring metric for Random Forests",
                "Because F1-score is the only metric that works with GridSearchCV's internal cross-validation mechanism"
            ],
            "answer": "Because F1-score balances precision and recall, which is important in a medical context where both false positives and false negatives matter, and accuracy alone can be misleading on imbalanced data"
        },
        {
            "question": "In the confusion matrix for the Random Forest, the model achieved 0 false positives and 5 false negatives. What is the clinical interpretation?",
            "options": [
                "The model is perfect — it made no errors of any kind on the test set",
                "The model never incorrectly flagged a benign tumor as malignant (no unnecessary biopsies), but it missed 5 actual cancers that went undiagnosed",
                "The model flagged all tumors as malignant, resulting in zero false positives but many false negatives",
                "The model's confusion matrix is incorrect because it is mathematically impossible to have zero false positives"
            ],
            "answer": "The model never incorrectly flagged a benign tumor as malignant (no unnecessary biopsies), but it missed 5 actual cancers that went undiagnosed"
        },
        {
            "question": "The malignant recall for the Random Forest in the CV comparison is 0.9514. What does this mean in practical terms?",
            "options": [
                "The model correctly identifies about 95% of all tumors in the dataset, both benign and malignant",
                "On average across the 10 folds, the model catches about 95% of actual malignant tumors, missing roughly 1 in 20 cancers",
                "The model has a 95% probability of being correct on any single prediction it makes",
                "The model's precision for the malignant class is 95%, meaning 95% of its positive predictions are correct"
            ],
            "answer": "On average across the 10 folds, the model catches about 95% of actual malignant tumors, missing roughly 1 in 20 cancers"
        },
        {
            "question": "Why does the malignant recall vary from 0.824 to 1.000 across the 10 folds in the single tree CV results?",
            "options": [
                "Because the single tree is highly sensitive to which specific samples end up in each fold, and some folds contain harder-to-classify cases than others",
                "Because the recall calculation is performed differently in each fold, producing inconsistent results",
                "Because the single tree uses a different random seed for each fold, leading to unpredictable performance",
                "Because the dataset contains exactly 10 malignant samples, and the model catches a different number in each fold"
            ],
            "answer": "Because the single tree is highly sensitive to which specific samples end up in each fold, and some folds contain harder-to-classify cases than others"
        },
        {
            "question": "In the bagging explanation, the notebook says 'each tree overfits to its specific bootstrap sample, but the errors are different across trees.' Why is it important that the errors are different?",
            "options": [
                "Because if all trees made the same errors, averaging their predictions would not cancel out those errors, and the ensemble would perform no better than a single tree",
                "Because different errors indicate that the trees are using different algorithms, which is a requirement for bagging to work",
                "Because the errors must be different in order for the OOB score to be computable",
                "Because different errors mean that some trees are overfitting while others are underfitting, creating a balanced ensemble"
            ],
            "answer": "Because if all trees made the same errors, averaging their predictions would not cancel out those errors, and the ensemble would perform no better than a single tree"
        },
        {
            "question": "What would happen to a Random Forest's performance if the number of features considered at each split (max_features) were set to 1?",
            "options": [
                "The model would achieve perfect accuracy because each split would be based on the single most important feature",
                "The model would likely underperform because each tree would be forced to split on essentially random single features, producing very weak individual trees that even averaging cannot fully compensate for",
                "The model would become equivalent to a single decision tree, as all trees would use the same single feature at every split",
                "The model would fail to train because Random Forests require at least 2 features at each split"
            ],
            "answer": "The model would likely underperform because each tree would be forced to split on essentially random single features, producing very weak individual trees that even averaging cannot fully compensate for"
        },
        {
            "question": "The notebook states that 'more trees doesn't always mean better.' Under what circumstances would adding more trees to a Random Forest stop improving performance?",
            "options": [
                "When the number of trees exceeds the number of features in the dataset, at which point additional trees have no new information to learn",
                "When the ensemble has already converged — adding more trees reduces variance only marginally because the law of large numbers has already taken effect",
                "When the training data is too small to support more than a certain number of trees, causing overfitting",
                "When the trees become too deep, at which point additional trees start to increase bias rather than reduce variance"
            ],
            "answer": "When the ensemble has already converged — adding more trees reduces variance only marginally because the law of large numbers has already taken effect"
        },
        {
            "question": "In the classification report, the Random Forest achieves a macro avg F1 of 0.97 and a weighted avg F1 of 0.97. Why are these two values so similar?",
            "options": [
                "Because the macro and weighted averages are always identical for Random Forest models regardless of the class distribution",
                "Because the class distribution (63/37) is not extremely imbalanced, so weighting by class frequency does not significantly change the average compared to treating both classes equally",
                "Because the model performs equally well on both classes, making the weighting factor irrelevant",
                "Because the F1-score is computed differently for macro and weighted averages, but the formulas happen to produce the same result for this dataset"
            ],
            "answer": "Because the class distribution (63/37) is not extremely imbalanced, so weighting by class frequency does not significantly change the average compared to treating both classes equally"
        },
        {
            "question": "If a hospital administrator asks 'How many cancers will this model miss?', which metric from the classification report or CV results would you cite, and why?",
            "options": [
                "Accuracy, because it gives the overall percentage of correct predictions across both classes",
                "Malignant recall, because it directly tells us what fraction of actual cancers the model catches, and its complement (1 - recall) tells us the miss rate",
                "Precision, because it tells us how reliable the model's positive predictions are",
                "F1-score, because it is the harmonic mean of precision and recall and therefore the most comprehensive single metric"
            ],
            "answer": "Malignant recall, because it directly tells us what fraction of actual cancers the model catches, and its complement (1 - recall) tells us the miss rate"
        },
        {
            "question": "The Random Forest's OOB score is 0.952 while its test accuracy is 0.971. Why might the OOB score be slightly lower than the test accuracy?",
            "options": [
                "Because the OOB score is computed on a smaller effective sample size (the out-of-bag portion of each bootstrap), making it a slightly more conservative estimate",
                "Because the OOB score is always lower than the test accuracy by a fixed mathematical constant",
                "Because the test set was accidentally included in the training data, inflating the test accuracy",
                "Because the OOB score uses a different evaluation metric than the test accuracy"
            ],
            "answer": "Because the OOB score is computed on a smaller effective sample size (the out-of-bag portion of each bootstrap), making it a slightly more conservative estimate"
        },
        {
            "question": "What is the key conceptual difference between how bagging and boosting handle model errors?",
            "options": [
                "Bagging corrects errors sequentially by reweighting samples, while boosting averages predictions in parallel",
                "Bagging averages independently trained models to cancel out uncorrelated errors, while boosting trains models sequentially with each one explicitly targeting the remaining errors of the ensemble",
                "Bagging uses deep trees to minimize errors, while boosting uses shallow trees to maximize them",
                "There is no conceptual difference — both methods average predictions from multiple models trained on the same data"
            ],
            "answer": "Bagging averages independently trained models to cancel out uncorrelated errors, while boosting trains models sequentially with each one explicitly targeting the remaining errors of the ensemble"
        }
    ],
    "18_5_3: Boosting and BART": [
        {
            "question": "How does AdaBoost differ from Gradient Boosting in how it handles errors?",
            "options": [
                "AdaBoost reweights misclassified samples; Gradient Boosting predicts residuals",
                "AdaBoost predicts residuals; Gradient Boosting reweights misclassified samples",
                "AdaBoost uses deep trees; Gradient Boosting uses shallow trees",
                "AdaBoost builds trees in parallel; Gradient Boosting builds trees sequentially"
            ],
            "answer": "AdaBoost reweights misclassified samples; Gradient Boosting predicts residuals"
        },
        {
            "question": "What is the 'shrinkage' concept in Gradient Boosting?",
            "options": [
                "Reducing the number of trees to prevent overfitting",
                "Using a smaller learning rate that requires more trees but often produces more robust models",
                "Limiting tree depth to reduce model complexity",
                "Removing features with low importance scores"
            ],
            "answer": "Using a smaller learning rate that requires more trees but often produces more robust models"
        },
        {
            "question": "What unique advantage does BART offer over standard ensemble methods?",
            "options": [
                "It trains faster than Random Forest",
                "It provides credible intervals (uncertainty quantification) for each prediction",
                "It requires no hyperparameter tuning",
                "It can handle categorical features without encoding"
            ],
            "answer": "It provides credible intervals (uncertainty quantification) for each prediction"
        },
        {
            "question": "Why are decision stumps (max_depth=1) used as base learners in AdaBoost?",
            "options": [
                "Because they are the fastest to train",
                "Because they are weak learners, leaving room for the sequential correction process to add value",
                "Because deeper stumps cause numerical instability",
                "Because sklearn only supports stumps for AdaBoost"
            ],
            "answer": "Because they are weak learners, leaving room for the sequential correction process to add value"
        },
        {
            "question": "In probability calibration, what does it mean if a model's curve is below the diagonal?",
            "options": [
                "The model underestimates probabilities",
                "The model overestimates probabilities",
                "The model is perfectly calibrated",
                "The model has high variance"
            ],
            "answer": "The model overestimates probabilities"
        },
    ],
    "18_5_4: Model Comparison": [
        {
            "question": "What does nested cross-validation provide that a single train/test split does not?",
            "options": [
                "Faster model training",
                "An unbiased performance estimate with quantifiable variance across folds",
                "More accurate predictions on the test set",
                "Automatic hyperparameter tuning without GridSearchCV"
            ],
            "answer": "An unbiased performance estimate with quantifiable variance across folds"
        },
        {
            "question": "In the nested CV setup for 18_5_4, what does the inner loop do?",
            "options": [
                "Evaluates the model on the held-out outer fold",
                "Tunes hyperparameters using GridSearchCV within each outer training fold",
                "Trains the final model on the full dataset",
                "Calculates the standard deviation across outer folds"
            ],
            "answer": "Tunes hyperparameters using GridSearchCV within each outer training fold"
        },
        {
            "question": "In a medical context, why might you prefer a model with slightly lower mean recall but lower variance over the model with the highest mean recall?",
            "options": [
                "Because lower variance means the model is faster to train",
                "Because a more consistent recall means the model is more reliable in clinical deployment \u2014 it won't occasionally miss many cancers",
                "Because lower variance models always have higher accuracy",
                "Because variance has no clinical significance"
            ],
            "answer": "Because a more consistent recall means the model is more reliable in clinical deployment \u2014 it won't occasionally miss many cancers"
        },
        {
            "question": "Why are the nested CV estimates typically slightly lower than single-split test scores?",
            "options": [
                "Because nested CV uses less data for training",
                "Because nested CV corrects for the optimistic bias introduced by hyperparameter tuning on the same data",
                "Because nested CV uses a different scoring metric",
                "Because nested CV has fewer folds than a single split"
            ],
            "answer": "Because nested CV corrects for the optimistic bias introduced by hyperparameter tuning on the same data"
        },
        {
            "question": "In the 18_5_4 comparison, why are red dots overlaid on the boxplots?",
            "options": [
                "To highlight outliers that should be removed",
                "To show the actual 5 outer fold data points, honestly revealing the limited sample size",
                "To indicate the best-performing fold for each model",
                "To show the mean and median values"
            ],
            "answer": "To show the actual 5 outer fold data points, honestly revealing the limited sample size"
        },
    ],
}


# --- QUIZ APP ---
class QuizApp:
    def __init__(self, quiz_name, data):
        self.quiz_name = quiz_name
        self.data = data
        self.current_index = 0
        self.score = 0
        self.user_answers = []

        # UI Elements
        self.header = widgets.HTML(value="<h2>" + quiz_name + "</h2>")
        self.progress = widgets.HTML(value="")
        self.question_text = widgets.HTML(value="")
        self.options = widgets.RadioButtons(options=[], layout={"width": "max-content"})
        self.submit_btn = widgets.Button(description="Submit Answer", button_style="primary")
        self.next_btn = widgets.Button(description="Next Question", button_style="info", disabled=True)
        self.back_btn = widgets.Button(description="Back to Menu", button_style="warning")
        self.feedback = widgets.HTML(value="")

        self.submit_btn.on_click(self.handle_submit)
        self.next_btn.on_click(self.handle_next)
        self.back_btn.on_click(self.handle_back)

        self.render_question()

    def render_question(self):
        clear_output(wait=True)
        q = self.data[self.current_index]
        self.progress.value = "<b>Question " + str(self.current_index + 1) + " of " + str(len(self.data)) + "</b>"
        self.question_text.value = "<p style='font-size:14px;'>" + q["question"] + "</p>"
        self.options.options = q["options"]
        self.options.value = None
        self.submit_btn.disabled = False
        self.next_btn.disabled = True
        self.feedback.value = ""

        display(self.header, self.progress, self.question_text, self.options,
                widgets.HBox([self.submit_btn, self.next_btn]), self.feedback)

    def handle_submit(self, b):
        if self.options.value is None:
            self.feedback.value = "<span style='color:red;'>Please select an option!</span>"
            return

        correct_answer = self.data[self.current_index]["answer"]
        if self.options.value == correct_answer:
            self.score += 1
            self.feedback.value = "<span style='color:green; font-weight:bold;'>Correct!</span>"
        else:
            self.feedback.value = "<span style='color:red; font-weight:bold;'>Incorrect.</span><br>The correct answer was: <b>" + correct_answer + "</b>"

        self.submit_btn.disabled = True
        self.next_btn.disabled = False

    def handle_next(self, b):
        self.current_index += 1
        if self.current_index < len(self.data):
            self.render_question()
        else:
            self.show_results()

    def handle_back(self, b):
        show_menu()

    def show_results(self):
        clear_output()
        percent = (self.score / len(self.data)) * 100
        result_html = """
        <div style="border: 2px solid #0366d6; padding: 20px; border-radius: 10px;">
            <h2>Quiz Complete!</h2>
            <p style="font-size:16px;">Your Final Score: <b>" + str(self.score) + " / " + str(len(self.data)) + "</b></p>
            <p style="font-size:20px; color:#0366d6;"><b>Percentage: " + "{:.1f}".format(percent) + "%</b></p>
        </div>
        """
        display(widgets.HTML(result_html), self.back_btn)


# --- MENU ---
def show_menu():
    clear_output(wait=True)
    header = widgets.HTML(value="<h2>18_5 Ensemble Methods -- Practice Quizzes</h2>")
    instruction = widgets.HTML(value="<p>Select a notebook quiz below to begin.</p>")
    quiz_selector = widgets.Dropdown(
        options=list(all_quizzes.keys()),
        description="Select Quiz:",
        layout={"width": "50%"}
    )
    start_btn = widgets.Button(description="Start Quiz", button_style="success")

    def on_start(b):
        selected = quiz_selector.value
        QuizApp(selected, all_quizzes[selected])

    start_btn.on_click(on_start)
    display(header, instruction, quiz_selector, start_btn)


# Start the app
show_menu()
# Out:
# HTML(value='<h2>18_5 Ensemble Methods -- Practice Quizzes</h2>')
# HTML(value='<p>Select a notebook quiz below to begin.</p>')
# Dropdown(description='Select Quiz:', layout=Layout(width='50%'), options=('18_5_0: Intro to Ensemble Methods',…
# Button(button_style='success', description='Start Quiz', style=ButtonStyle())
