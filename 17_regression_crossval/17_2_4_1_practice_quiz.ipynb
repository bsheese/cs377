# %% [markdown]
# <a href="https://colab.research.google.com/github/bsheese/cs377/blob/main/17_regression_crossval/17_2_4_1_practice_quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Run the cell below to start the practice quiz.

# %%
# @title
import os
import requests

# 1. Download the engine if it doesn't exist in the local Colab env
if not os.path.exists('quiz_engine.py'):
    url = 'https://raw.githubusercontent.com/bsheese/cs377/main/quiz_engine.py'
    r = requests.get(url)
    with open('quiz_engine.py', 'w') as f:
        f.write(r.text)

# 2. Now import it
from quiz_engine import QuizApp
from IPython.display import display

# 3. Define your quiz data
quiz_data = [
    {"question": "What is the primary purpose of 'One-Hot Encoding' in the context of the Ames dataset?", "options": ["To normalize numeric features", "To convert categorical text into numeric 1s and 0s", "To handle outliers in the target variable", "To reduce the number of features"], "answer": "To convert categorical text into numeric 1s and 0s"},
    {"question": "Why is 'drop_first=True' critical when creating dummy variables for linear models?", "options": ["It prevents the 'Dummy Variable Trap' (perfect multicollinearity)", "It makes the model run faster", "It automatically log-transformed the data", "It removes rows with missing values"], "answer": "It prevents the 'Dummy Variable Trap' (perfect multicollinearity)"},
    {"question": "In the provided code, why is a 'Pipeline' used during cross-validation?", "options": ["To speed up the OLS algorithm", "To prevent data leakage by ensuring scaling is only fit on training folds", "To allow the use of categorical data without encoding", "To automatically calculate VIF scores"], "answer": "To prevent data leakage by ensuring scaling is only fit on training folds"},
    {"question": "What does Scikit-Learn's 'SequentialFeatureSelector' do in 'forward' mode?", "options": ["Removes the worst features one by one", "Starts empty and adds the best feature at each step", "Checks all possible combinations of features simultaneously", "Only selects features with a VIF below 5"], "answer": "Starts empty and adds the best feature at each step"},
    {"question": "Why would you use only 2 or 3 cross-validation folds instead of 10 during model development?", "options": ["It is more accurate for large datasets", "To reduce computation time during expensive feature selection", "Because OLS cannot handle more than 5 folds", "To ensure the R-squared value is higher"], "answer": "To reduce computation time during expensive feature selection"},
    {"question": "If 'Bedroom AbvGr' has a negative coefficient while 'Gr Liv Area' is held constant, what is the interpretation?", "options": ["Houses with more bedrooms are always cheaper", "More bedrooms in the same square footage leads to smaller, less desirable rooms", "The model is fundamentally broken", "Bedrooms have no impact on house price"], "answer": "More bedrooms in the same square footage leads to smaller, less desirable rooms"},
    {"question": "In a 'Residuals vs. Predicted Values' plot, what does a 'fan' or 'funnel' shape indicate?", "options": ["The model is perfect", "Heteroscedasticity (non-constant error variance)", "The features are highly correlated", "The target variable is normally distributed"], "answer": "Heteroscedasticity (non-constant error variance)"},
    {"question": "What is the primary goal of log-transforming a right-skewed target variable?", "options": ["To make the coefficients larger", "To handle non-linear features", "To squash extreme values and make the distribution more 'normal'", "To eliminate the need for a constant intercept"], "answer": "To squash extreme values and make the distribution more 'normal'"},
    {"question": "In the context of OLS, why can we use a squared term ($X^2$) and still call it a 'linear' model?", "options": ["Because the resulting graph is a straight line", "Because the model is linear in its parameters (coefficients)", "Because $X^2$ is always a straight line", "Because we use a linear scaler"], "answer": "Because the model is linear in its parameters (coefficients)"},
    {"question": "Adding a squared term ($X^2$) to a model allows the regression line to:", "options": ["Stay perfectly horizontal", "Bend exactly once (forming a parabola)", "Become a step-function", "Ignore all outliers"], "answer": "Bend exactly once (forming a parabola)"},
    {"question": "What does a negative coefficient for a squared term (e.g., $-X^2$) typically represent in real estate data?", "options": ["Exponential growth", "Diminishing returns (curve flattens out as $X$ increases)", "A perfectly linear relationship", "Data corruption"], "answer": "Diminishing returns (curve flattens out as $X$ increases)"},
    {"question": "Why is it dangerous to use high-degree polynomials (e.g., $X^5$ or $X^{10}$)?", "options": ["The model becomes too simple", "It leads to overfitting and a 'wiggly' line that predicts poorly on new data", "OLS cannot solve equations above degree 2", "The R-squared will always be 0"], "answer": "It leads to overfitting and a 'wiggly' line that predicts poorly on new data"},
    {"question": "What is 'structural multicollinearity' in polynomial regression?", "options": ["Correlation caused by the inherent nature of the raw data", "Correlation between a base feature ($X$) and its derived square ($X^2$)", "Correlation between the target and the features", "Missing data in the categorical columns"], "answer": "Correlation between a base feature ($X$) and its derived square ($X^2$)"},
    {"question": "What is a common technique to reduce structural multicollinearity before squaring a feature?", "options": ["Log-transforming the feature", "Centering or standardizing the feature", "Deleting the original linear feature", "Removing the intercept"], "answer": "Centering or standardizing the feature"},
    {"question": "What does the Variance Inflation Factor (VIF) measure?", "options": ["The accuracy of the model", "How much the variance of a coefficient is 'inflated' due to correlation with other predictors", "The number of outliers in the data", "The speed of the forward selection process"], "answer": "How much the variance of a coefficient is 'inflated' due to correlation with other predictors"},
    {"question": "Which VIF score is generally considered a 'red flag' indicating problematic multicollinearity?", "options": ["VIF = 0", "VIF = 1", "VIF > 5 or 10", "VIF < 2"], "answer": "VIF > 5 or 10"},
    {"question": "If 'Overall Qual' and 'Overall Qual Squared' are both positive, the curve represents:", "options": ["Diminishing returns", "Accelerating/Exponential-like growth", "A straight horizontal line", "A downward trend"], "answer": "Accelerating/Exponential-like growth"},
    {"question": "In the Ames analysis, 'Gr Liv Area' had a VIF of ~118. What does this suggest?", "options": ["It is the only important variable", "It is highly redundant with other square-footage variables", "The data was collected incorrectly", "It is perfectly independent of other variables"], "answer": "It is highly redundant with other square-footage variables"},
    {"question": "What is the 'ideal' VIF score for a completely independent feature?", "options": ["0", "1", "10", "-1"], "answer": "1"},
    {"question": "When interpreting a regression heatmap, a value of 1.0 between two independent variables suggests:", "options": ["Perfect independence", "Perfect multicollinearity", "A negative relationship", "Normal distribution"], "answer": "Perfect multicollinearity"},
    {"question": "If forward selection excludes a polynomial term you expected to be important, why might that happen?", "options": ["Forward selection doesn't support math", "Other features already capture that predictive power", "The R-squared is already too high", "Polynomials can only be used with backward selection"], "answer": "Other features already capture that predictive power"},
    {"question": "Why is 'StandardScaler' applied inside the Pipeline rather than to the whole dataset at once?", "options": ["To make the data look better", "To prevent data leakage from the test/validation folds into the training process", "To make sure the target variable is scaled", "Because Scikit-Learn requires it"], "answer": "To prevent data leakage from the test/validation folds into the training process"},
    {"question": "A 'hockey stick' curve in house prices (upward bend) suggests that:", "options": ["Quality increases don't matter", "High-end luxury finishes command an exponential premium", "The house is losing value over time", "The model has high bias"], "answer": "High-end luxury finishes command an exponential premium"},
    {"question": "In the 'run_modeling_workflow' function, what is 'random_state=42' used for?", "options": ["To improve the R-squared", "To ensure the train-test split is reproducible", "To shuffle the columns", "To identify outliers"], "answer": "To ensure the train-test split is reproducible"},
    {"question": "If your model has high R-squared on training data but low R-squared on test data, it is:", "options": ["Underfitting", "Overfitting", "Perfectly Balanced", "Biased"], "answer": "Overfitting"},
    {"question": "Which metric does the provided code use to evaluate the error of the model?", "options": ["R-squared", "Mean Squared Error (MSE)", "Mean Absolute Error (MAE)", "VIF"], "answer": "Mean Squared Error (MSE)"},
    {"question": "Backward selection starts with:", "options": ["No features", "All features", "A random set of features", "Only categorical features"], "answer": "All features"},
    {"question": "Why is 'Gr Liv Area' often the strongest predictor in the Ames dataset?", "options": ["Because it's a log-transform", "Because square footage is a primary driver of home value", "Because it has the lowest VIF", "Because it was one-hot encoded"], "answer": "Because square footage is a primary driver of home value"},
    {"question": "When a residual plot shows random scatter around the zero line, it suggests:", "options": ["The model is failing", "The linear assumptions are appropriate", "There is high multicollinearity", "The model is overfitting"], "answer": "The linear assumptions are appropriate"},
    {"question": "What is the primary advantage of 'Forward Selection' over 'All Possible Subsets'?", "options": ["It is more accurate", "It is computationally much faster", "It ignores multicollinearity", "It doesn't require a target variable"], "answer": "It is computationally much faster"}
]

# 4. Launch
app = QuizApp(quiz_data, title="Practice Quiz")
display(app.ui)
