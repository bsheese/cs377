# %% [markdown]
# <a href="https://colab.research.google.com/github/bsheese/cs377/blob/main/17_regression_crossval/17_2_4_1_practice_quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Run the cell below to start the practice quiz.

# %%
# @title
import os
import requests

# 1. Download the engine if it doesn't exist in the local Colab env
if not os.path.exists('quiz_engine.py'):
    url = 'https://raw.githubusercontent.com/bsheese/cs377/main/quiz_engine.py'
    r = requests.get(url)
    with open('quiz_engine.py', 'w') as f:
        f.write(r.text)

# 2. Now import it
from quiz_engine import QuizApp
from IPython.display import display

# 3. Define your quiz data
quiz_data = [
    {"question": "In data cleaning, what is the primary conceptual reason for removing 'extreme outliers' (like very large houses sold for very low prices) before building a linear model?", "options": ["To increase the size of the dataset", "To prevent a few unusual observations from disproportionately skewing the regression line", "To ensure the model can only predict luxury home prices", "Because linear regression cannot mathematically process large numbers"], "answer": "To prevent a few unusual observations from disproportionately skewing the regression line"},
    {"question": "Why is it conceptually important to remove unique identifiers like 'PID' or 'Order' from a machine learning featureset?", "options": ["They are too large to store in memory", "They are strings and linear regression requires numbers", "They provide no generalizable information and could lead to 'memorizing' specific rows", "They are always perfectly correlated with the target variable"], "answer": "They provide no generalizable information and could lead to 'memorizing' specific rows"},
    {"question": "What is the statistical problem with a 'monotonic' feature (a column where every single value is the same)?", "options": ["It has zero variance and therefore provides no predictive information", "It will cause the model to crash due to 'division by zero'", "It makes the R-squared value too high to be realistic", "It is considered a 'yolked' variable"], "answer": "It has zero variance and therefore provides no predictive information"},
    {"question": "The notebook describes 'yolked features' (e.g., Pool Quality and Pool Area). What is the primary concern when these two features are included in a model together?", "options": ["They represent redundant information where one value is structurally dependent on the other", "They are always missing from the dataset at the same time", "They are measured in different units", "They cause the target variable to become right-skewed"], "answer": "They represent redundant information where one value is structurally dependent on the other"},
    {"question": "If a house has 'None' for a basement category and '0' for basement square footage, what does this tell us about the relationship between these features?", "options": ["The data is corrupted", "The categorical 'None' is a structural prerequisite for the numerical '0'", "The two variables are independent", "One is an outlier of the other"], "answer": "The categorical 'None' is a structural prerequisite for the numerical '0'"},
    {"question": "Why would a data scientist choose to drop a feature like 'Pool Area' if 99% of the entries are zero?", "options": ["Because zeros cannot be used in a linear regression", "To reduce 'noise' and complexity in the model for a very small gain in predictive power", "Because the model only works for houses with pools", "To ensure the dataset is perfectly balanced"], "answer": "To reduce 'noise' and complexity in the model for a very small gain in predictive power"},
    {"question": "In the context of 'Garage Yr Blt', why is it dangerous to simply replace missing values with '0'?", "options": ["Because a year of '0' acts as a massive outlier that distorts the temporal logic of the model", "Because Python does not recognize 0 as a valid year", "Because it will make the house appear newer than it actually is", "Because 0 is reserved for categorical data only"], "answer": "Because a year of '0' acts as a massive outlier that distorts the temporal logic of the model"},
    {"question": "What is the conceptual goal of 'collapsing' a categorical variable with 10 categories into just 'Category A' and 'Other'?", "options": ["To increase the number of features in the model", "To simplify the model and prevent 'sparsity' (too many columns with mostly zeros)", "To make the data more difficult to interpret", "To ensure the model is non-linear"], "answer": "To simplify the model and prevent 'sparsity' (too many columns with mostly zeros)"},
    {"question": "Why do we check for 'unbalanced' categoricals (e.g., where 95% of houses are on a 'Paved Street')?", "options": ["Because we want to find the most popular type of house", "Because variables with very little variance provide almost no 'signal' for the model to learn from", "Because linear regression requires a 50/50 split in all categories", "To identify which houses are the most expensive"], "answer": "Because variables with very little variance provide almost no 'signal' for the model to learn from"},
    {"question": "Consider the code: `df['garage_attached'] = np.where(df['Garage Type'] == 'Attchd', 1, 0)`. What is the logical purpose of this transformation?", "options": ["To delete the 'Garage Type' column", "To create a binary indicator (dummy variable) focusing on one specific attribute", "To calculate the average price of attached garages", "To normalize the garage area"], "answer": "To create a binary indicator (dummy variable) focusing on one specific attribute"},
    {"question": "What is the primary benefit of converting binary string columns (like 'Yes'/'No') into the 'boolean' or 'bool' data type?", "options": ["It makes the file size larger", "It clearly communicates to the model (and the programmer) that the data is a logical toggle", "It allows the model to handle missing values automatically", "It prevents the data from being used in a heatmap"], "answer": "It clearly communicates to the model (and the programmer) that the data is a logical toggle"},
    {"question": "In the code `df.dropna(how='all')`, what is the specific condition required to remove a row?", "options": ["The row must have at least one missing value", "The row must be entirely composed of missing values", "The row must be a duplicate of another row", "The row must have a missing Sale Price"], "answer": "The row must be entirely composed of missing values"},
    {"question": "When dealing with 'unbalanced' numeric data (e.g., a feature that is 85% zero), why might we convert it to a binary '0 or 1' instead of leaving it as a continuous number?", "options": ["To make the model more complex", "Because the presence/absence of the feature is likely more informative than the specific amount", "Because linear regression cannot handle the number 0", "To ensure the mean and median are the same"], "answer": "Because the presence/absence of the feature is likely more informative than the specific amount"},
    {"question": "What is the conceptual logic behind using 'median replacement' for missing numeric data instead of 'mean replacement'?", "options": ["The median is always higher than the mean", "The median is more robust to outliers and better represents the 'typical' value in skewed data", "The mean is mathematically impossible to calculate with missing data", "The median is only used for categorical data"], "answer": "The median is more robust to outliers and better represents the 'typical' value in skewed data"},
    {"question": "If we planned to use a more complex model (like a Neural Network) instead of Multiple Linear Regression, how might our data cleaning strategy change?", "options": ["We would probably remove even more data", "We might leave in more features and perform less aggressive 'simplification'", "We would only use categorical data", "We would never remove outliers"], "answer": "We might leave in more features and perform less aggressive 'simplification'"},
    {"question": "What is the risk of having too many 'one-hot encoded' columns in a linear model?", "options": ["The model will become too simple", "The model may suffer from the 'curse of dimensionality,' making it harder to find a stable solution", "The model will automatically delete the target variable", "The R-squared will always be negative"], "answer": "The model may suffer from the 'curse of dimensionality,' making it harder to find a stable solution"},
    {"question": "Why is the `safe_drop` function used instead of just calling `df.drop()`?", "options": ["It makes the code run significantly faster", "It prevents the code from crashing if you run the same cell twice or if a column is already gone", "It automatically saves a copy of the dropped data to the hard drive", "It only drops rows, never columns"], "answer": "It prevents the code from crashing if you run the same cell twice or if a column is already gone"},
    {"question": "The notebook mentions 'Structural Multicollinearity' when discussing yolked variables. Conceptually, what is multicollinearity?", "options": ["When the target variable is normally distributed", "When independent variables (features) are highly correlated with each other", "When the model has too many rows", "When the errors are random"], "answer": "When independent variables (features) are highly correlated with each other"},
    {"question": "When the code uses `df.select_dtypes(include=np.number)`, what is it attempting to isolate?", "options": ["Only the target variable", "Columns that contain continuous or discrete quantitative data", "Columns that are categorical in nature", "Columns that have no missing values"], "answer": "Columns that contain continuous or discrete quantitative data"},
    {"question": "Why is 'Year Sold' or 'Month Sold' sometimes considered an 'unbalanced' or 'uninformative' categorical variable in a housing dataset?", "options": ["Because people only buy houses in the summer", "Because if the distribution is nearly even or lacks a strong trend, it adds complexity without predictive gain", "Because years are numbers and cannot be categories", "Because the model already knows the current year"], "answer": "Because if the distribution is nearly even or lacks a strong trend, it adds complexity without predictive gain"},
    {"question": "What does the phrase 'Data cleaning is dictated by the model choice' mean in this context?", "options": ["All models require the exact same cleaning steps", "The assumptions and limitations of Multiple Linear Regression require specific data shapes (like linearity and lack of noise)", "The data is cleaned by the computer automatically once a model is chosen", "You should only clean data after the model is finished"], "answer": "The assumptions and limitations of Multiple Linear Regression require specific data shapes (like linearity and lack of noise)"},
    {"question": "When collapsing 'Foundation' into 'PConc', 'CBlock', and 'Other', why group the less frequent foundations into 'Other'?", "options": ["Because they are probably errors in the data", "To ensure the model has enough observations in each category to find a reliable coefficient", "To make the houses in the 'Other' category more expensive", "Because linear regression can only handle three categories maximum"], "answer": "To ensure the model has enough observations in each category to find a reliable coefficient"},
    {"question": "What is the purpose of using `value_counts(normalize=True)` during the cleaning process?", "options": ["To see the raw count of every value", "To see the proportion (percentage) of the data belonging to each category", "To find the mean of a categorical variable", "To identify and remove duplicates"], "answer": "To see the proportion (percentage) of the data belonging to each category"},
    {"question": "If a feature is 90% 'Standard Circuit' and 10% other values, why would a modeler consider dropping it?", "options": ["Standard circuit breakers are not important for house prices", "The lack of variation means the feature likely won't help the model differentiate between expensive and cheap houses", "Because 10% is too much missing data", "Because categorical data must be 100% consistent"], "answer": "The lack of variation means the feature likely won't help the model differentiate between expensive and cheap houses"},
    {"question": "In the context of the Ames dataset, what does 'Gr Liv Area' represent conceptually?", "options": ["Green Living Area (eco-friendly space)", "Gross Living Area (above-grade square footage)", "Ground Level Area only", "Garage and Living Area combined"], "answer": "Gross Living Area (above-grade square footage)"},
    {"question": "Why is it important to look at the `.info()` output's 'Non-Null Count'?", "options": ["To determine how many features are in the dataset", "To identify which columns have missing data that require imputation or dropping", "To see the memory usage of the dataframe", "To check the data types of the target variable"], "answer": "To identify which columns have missing data that require imputation or dropping"},
    {"question": "The notebook describes dropping 'Misc Feature' and 'Misc Val.' What is the trade-off being made here?", "options": ["Trading accuracy for speed", "Trading potential niche information for a simpler, less 'noisy' model", "Trading categorical data for numerical data", "Trading training data for test data"], "answer": "Trading potential niche information for a simpler, less 'noisy' model"},
    {"question": "Why is it standard practice to perform outlier removal *before* calculating medians for imputation?", "options": ["Outliers can skew the median (though less than the mean), so removing them first ensures a more representative 'typical' value", "The median cannot be calculated if outliers are present", "To increase the number of missing values", "Because the author recommended it"], "answer": "Outliers can skew the median (though less than the mean), so removing them first ensures a more representative 'typical' value"},
    {"question": "What is the primary risk of 'over-cleaning' your data (dropping too many columns)?", "options": ["The model will become too complex to understand", "You might remove a feature that actually has a strong, unique relationship with the target variable", "The computer will run out of memory", "The dataset will become too large"], "answer": "You might remove a feature that actually has a strong, unique relationship with the target variable"},
    {"question": "What does the code `df.loc[~df['Foundation'].isin(['PConc', 'CBlock']), 'Foundation'] = 'Other'` do?", "options": ["It deletes all foundations that are 'PConc' or 'CBlock'", "It labels any foundation type that is NOT 'PConc' or 'CBlock' as 'Other'", "It creates a new dataframe containing only 'Other' foundations", "It checks if 'Foundation' is a numeric column"], "answer": "It labels any foundation type that is NOT 'PConc' or 'CBlock' as 'Other'"}
]
# 4. Launch
app = QuizApp(quiz_data, title="Practice Quiz")
display(app.ui)
