# %% [markdown]
# # 06 — Pandas Intro: Practice Quiz
#
# Run the cell below to launch the interactive quiz.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))
from quiz_engine import QuizApp

quiz_data = [{'question': 'What does `pd.Series([10, 20, 30]).iloc[1]` return?', 'options': ['10', '20', '30', 'An error — iloc requires a label'], 'answer': '20'}, {'question': "You run `s = pd.Series({'a': 1, 'b': 2, 'c': 3})`. What is `s.loc['b']`?", 'options': ['1', '2', '3', 'KeyError'], 'answer': '2'}, {'question': 'Which method produces a statistical summary (count, mean, std, min, max) of a Series?', 'options': ['.info()', '.describe()', '.summary()', '.stats()'], 'answer': '.describe()'}, {'question': "What does `df[['name', 'age']]` return?", 'options': ['A Series with two elements', 'A DataFrame with two columns', 'A list of two Series', 'An error — use .loc[] for multiple columns'], 'answer': 'A DataFrame with two columns'}, {'question': 'Which selector always uses integer positions, regardless of the index?', 'options': ['.loc[]', '.iloc[]', '.at[]', '[]'], 'answer': '.iloc[]'}, {'question': 'You want rows where age > 30 AND pclass == 1. Which expression is correct?', 'options': ["df[df['age'] > 30 and df['pclass'] == 1]", "df[(df['age'] > 30) & (df['pclass'] == 1)]", "df[(df['age'] > 30) | (df['pclass'] == 1)]", 'df.filter(age > 30, pclass == 1)'], 'answer': "df[(df['age'] > 30) & (df['pclass'] == 1)]"}, {'question': 'After filtering a DataFrame, you want to add a new column to the result without affecting the original. What should you do first?', 'options': ['Use inplace=True', 'Call .copy() on the filtered result', 'Assign directly — pandas handles this automatically', 'Reset the index before assigning'], 'answer': 'Call .copy() on the filtered result'}, {'question': "Which method fills missing values with the string 'Unknown'?", 'options': ["df['col'].dropna('Unknown')", "df['col'].replace(NaN, 'Unknown')", "df['col'].fillna('Unknown')", "df['col'].isnull() = 'Unknown'"], 'answer': "df['col'].fillna('Unknown')"}, {'question': "What does `df.groupby('sex')['survived'].mean()` compute?", 'options': ['The average survival value for the entire dataset', "The mean of the 'sex' column", "The survival rate for each unique value of 'sex'", 'The number of survivors grouped by sex'], 'answer': "The survival rate for each unique value of 'sex'"}, {'question': "You have a GroupBy result where 'pclass' is the index. You want it as a regular column. What do you call?", 'options': ['.set_index()', '.reset_index()', '.reindex()', '.drop_index()'], 'answer': '.reset_index()'}, {'question': 'What is the main difference between pd.crosstab() and pd.pivot_table()?', 'options': ['crosstab is faster; pivot_table is slower', 'crosstab counts observations; pivot_table aggregates any numeric column with any function', 'pivot_table only works with dates; crosstab works with any data', 'They are identical — just different syntax'], 'answer': 'crosstab counts observations; pivot_table aggregates any numeric column with any function'}, {'question': "What does pd.crosstab(df['sex'], df['survived'], normalize='index') produce?", 'options': ['Counts of each sex/survived combination', 'Proportions across the entire table summing to 1', 'Proportions within each sex group — each row sums to 1', 'Proportions within each survived group — each column sums to 1'], 'answer': 'Proportions within each sex group — each row sums to 1'}]

app = QuizApp(quiz_data, 'Pandas Intro Quiz')
app.run()
